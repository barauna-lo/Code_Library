# %% [markdown]
# <a href="https://colab.research.google.com/github/barauna-lo/Code_Library/blob/main/chatGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![índice.jpeg](data:image/jpeg;base64,...)

# %%
import json
import requests

# Define sua chave de API e endpoint

api_key = "SUA_CHAVE_API" 
endpoint = "https://api.openai.com/v1/engines/davinci/completions"

# Define o texto de entrada e as configurações do modelo

prompt = "Escreva algo sobre o Python" 
model = "text-davinci-002"

# Cria o corpo da solicitação

data = {
    "prompt": prompt,
    "model": model,
    "max_tokens": 100
    }

# Envia a solicitação à API

response = requests.post(endpoint, json-data, headers={
    "Content-Type": "application/json",
    "Authorization": "Bearer (api_key}"
    })

# Imprime a resposta 
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f8fbfdb429fe> in <module>
#      22 # Envia a solicitação à API
#      23
# ---> 24 response = requests.post(endpoint, json-data, headers={
#      25     "Content-Type": "application/json",
#      26     "Authorization": "Bearer (api_key}"
#
# TypeError: unsupported operand type(s) for -: 'module' and 'dict'
